# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import sys
sys.path.append('Perceptron/perceptron.py')
from .perceptron import Perceptron
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-bc9d5a63d9c6> in <module>
#       7 import sys
#       8 sys.path.append('Perceptron/perceptron.py')
# ----> 9 from .perceptron import Perceptron
#
# ImportError: attempted relative import with no known parent package

# %%
X, y = datasets.make_blobs(n_samples=150, n_features=2, centers=2, cluster_std=1.05, random_state=2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

p = Perceptron(1000)
p.fit(X_train, y_train)
pred = p.predict(X_test)
p.log_metrics(y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-edb12b5cb317> in <module>
#       2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
#       3
# ----> 4 p = Perceptron(1000)
#       5 p.fit(X_train, y_train)
#       6 pred = p.predict(X_test)
#
# NameError: name 'Perceptron' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.scatter(X_train[:, 0], X_train[:, 1], marker='x', c=y_train)

x1 = np.amin(X_train[:, 0])
x2 = np.amax(X_train[:, 0])

y1 = (-p.weights[0] * x1 - p.bias) / p.weights[1]
y2 = (-p.weights[0] * x2 - p.bias) / p.weights[1]

ax.plot([x1, x2], [y1, y2], 'k')
ax.set_title('Decision Boundary on Test Dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7a6e89d36b00> in <module>
#       6 x2 = np.amax(X_train[:, 0])
#       7
# ----> 8 y1 = (-p.weights[0] * x1 - p.bias) / p.weights[1]
#       9 y2 = (-p.weights[0] * x2 - p.bias) / p.weights[1]
#      10
#
# NameError: name 'p' is not defined
